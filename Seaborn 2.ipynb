# %%
## import libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# import data 
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# basic checks from the data (shape,no of rows ,no of cloumns,name of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.shape
# Out:
# (244, 7)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.describe(include='category') 
#categorical data
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
 # Insights
Count shows the total number of non-null observations  in each column.
Unique indicates the number of distinct categories present in each column 
Non-smokers form the majority.
Saturday has the highest number of sales and customer visits (87 records).
Most visits occur during dinner time, with 176 customer visits.

# %%
df.describe() #numerical data
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# Insights
The dataset contains 244 records with no missing values.
The average total bill is about 19.79, while the average tip is around 3.00.
Most groups consist of 2–3 people, with an average group size of about 2.57.
The minimum total bill is 3.07 and the maximum is 50.81 show the spreading .
Tips range from 1.00 to 10.00, shows the variation in tip.
The median total bill (17.80) is slightly lower than the mean, suggesting some high-value bills.
The 75% of customers have group sizes of 3 or fewer, showing smaller groups are more common.

# %%
# null value analysis and the imputation
A.fill the missing records:
  1.mean, median ,mode
  2.domain
B.remove the missing value
 1.remove the rows in which missing position
    dropna() the row will be deleted if the missing values are there(if data loss is < 20 we can remove,else should not remove)
 2.remove the columns in which missing position 
    remove the columns on the basis of the missing values 
df.isnull().sum()
df.isna().sum()  # to know the null values
df.isna().sum()/df.shape[0])*100 # to get the percentage
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.isnull().sum()
df.isna().sum()
(df.isna().sum()/df.shape[0])*100
# Out:
# total_bill    0.0
# tip           0.0
# sex           0.0
# smoker        0.0
# day           0.0
# time          0.0
# size          0.0
# dtype: float64

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df.dropna() # dorp the null value rows
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.shape
# Out:
# (891, 15)

# %%
df.dropna().shape
# Out:
# (182, 15)

# %%
((df.shape[0]-df.dropna().shape[0])/df.shape[0])*100 # ((891-182))/891)*100  it removes 80% so no need of t his
# Out:
# 79.57351290684625

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
#to fill age - median # if the column is numerical go with the median
#embarked - mode
#embark_town - mode # if the cloumn is categorical go with mode 
# deck - drop the row(perct og the record is more than 20  soo remove it )

# %%
df.drop('deck',axis=1,inplace=True)

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df['age'].fillna(df['age'].median(),inplace=True)
df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)
df['embark_town'].fillna(df['embark_town'].mode()[0], inplace=True)
df.isnull().sum()
# Out:
# C:\Users\ASUS TUF\AppData\Local\Temp\ipykernel_1724\774284298.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(),inplace=True)
# C:\Users\ASUS TUF\AppData\Local\Temp\ipykernel_1724\774284298.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
#UNIVARIANT  ANALYSIS(analysis on the single column is univarient)
1.numeric 
   histogram
2.categorical
   countplot

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  891 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
## histogram for numerical values
plt.figure(figsize=(2,2))
sns.histplot(x=df['survived'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['age'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['pclass'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['sibsp'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'],kde=True)
plt.show()

# %%
#categorical
plt.figure(figsize=(2,2))
sns.countplot(x=df['sex'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['deck'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['alone'])
plt.show()

# %%
plt.figure(figsize=(3,3))
sns.countplot(x=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['alive'])
plt.show()

# %%
# BI VARIATE ANALYSIS
#1.HISTOGRAM
plt.figure(figsize=(2,2))
sns.histplot(x=df['survived'],hue=df['sex'],kde=True)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['age'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['pclass'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['sibsp'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['parch'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['fare'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['survived'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['age'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['pclass'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['sibsp'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['parch'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['fare'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['survived'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['age'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['pclass'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['sibsp'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['parch'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['fare'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['survived'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['age'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['pclass'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['sibsp'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['parch'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['fare'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['survived'],hue=df['adult_male'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['age'],hue=df['adult_male'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['pclass'],hue=df['adult_male'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['sibsp'],hue=df['adult_male'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['parch'],hue=df['adult_male'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['fare'],hue=df['adult_male'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['survived'],hue=df['embark_town'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['age'],hue=df['embark_town'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['pclass'],hue=df['embark_town'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['sibsp'],hue=df['embark_town'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['parch'],hue=df['embark_town'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['fare'],hue=df['embark_town'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['survived'],hue=df['alive'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['age'],hue=df['alive'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['pclass'],hue=df['alive'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['sibsp'],hue=df['alive'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['parch'],hue=df['alive'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['fare'],hue=df['alive'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['survived'],hue=df['alone'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['age'],hue=df['alone'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['sibsp'],hue=df['alone'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['parch'],hue=df['alone'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['pclass'],hue=df['alone'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['fare'],hue=df['alone'],kde=True)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['survived'],hue=df['deck'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['age'],hue=df['deck'],kde=True)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.histplot(x=df['pclass'],hue=df['deck'],kde=True)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['sex'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['sex'],hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['sex'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['sex'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['sex'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['sex'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['sex'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['embarked'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['embarked'],hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['embarked'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['embarked'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['embarked'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['embarked'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['embarked'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['class'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['class'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['class'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['class'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['class'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['class'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['class'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['who'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['who'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['who'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['who'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['who'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['who'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['adult_male'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['adult_male'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['adult_male'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['adult_male'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['adult_male'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['adult_male'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['embark_town'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['adult_male'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['adult_male'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['adult_male'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['adult_male'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['adult_male'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['alone'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['alone'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['alone'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['alone'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['alone'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['alone'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['alive'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['alive'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['alive'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['alive'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['alive'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['alive'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['who'],hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['alive'],hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['alone'],hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['adult_male'],hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['embark_town'],hue=df['class'])
plt.show()

# %%
# bivariant (scatter plot)
plt.figure()
sns.scatterplot(x=df['survived'],y=df['age'])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  891 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['pclass'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['sibsp'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['parch'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['fare'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['survived'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['pclass'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['sibsp'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['fare'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['parch'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['pclass'],y=df['survived'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['pclass'],y=df['age'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['pclass'],y=df['sibsp'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['pclass'],y=df['parch'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['pclass'],y=df['fare'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['survived'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['age'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['sibsp'],y=df['pclass'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['sibsp'],y=df['parch'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['sibsp'],y=df['fare'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['parch'],y=df['survived'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['sibsp'],y=df['age'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['sibsp'],y=df['pclass'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['sibsp'],y=df['parch'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['sibsp'],y=df['fare'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['parch'],y=df['survived'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['parch'],y=df['age'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['parch'],y=df['pclass'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['parch'],y=df['sibsp'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['parch'],y=df['fare'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['fare'],y=df['survived'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['fare'],y=df['age'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['fare'],y=df['pclass'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['fare'],y=df['parch'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(x=df['fare'],y=df['sibsp'])
plt.show()

# %%
# bivariant (bar plot)
plt.figure(figsize=(2,2))
sns.barplot(x=df['age'],y=df['sex'])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  891 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['age'],y=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['age'],y=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['age'],y=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['age'],y=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['age'],y=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['age'],y=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['age'],y=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['survived'],y=df['sex'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['survived'],y=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['survived'],y=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['survived'],y=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['survived'],y=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['survived'],y=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['survived'],y=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['survived'],y=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['pclass'],y=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['pclass'],y=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['pclass'],y=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['pclass'],y=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['pclass'],y=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['pclass'],y=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['pclass'],y=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['sibsp'],y=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['sibsp'],y=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['sibsp'],y=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['sibsp'],y=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['sibsp'],y=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['sibsp'],y=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['sibsp'],y=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['parch'],y=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['parch'],y=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['parch'],y=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['parch'],y=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['parch'],y=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['parch'],y=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['parch'],y=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['fare'],y=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['fare'],y=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['fare'],y=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['fare'],y=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['fare'],y=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['fare'],y=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.barplot(x=df['fare'],y=df['alone'],estimator='mean')
plt.show()

# %%
## univarient (box plot=to find the outliers)
# outliers are errors 
plt.figure(figsize=(2,2))
sns.boxplot(x=df['survived'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['age'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['sibsp'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['pclass'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['parch'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['fare'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['survived'],y=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['survived'],y=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['survived'],y=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['survived'],y=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['survived'],y=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['survived'],y=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['survived'],y=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['age'],y=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['age'],y=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['age'],y=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['age'],y=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['age'],y=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['age'],y=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['age'],y=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['sibsp'],y=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['sibsp'],y=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['sibsp'],y=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['sibsp'],y=df['adult_male'])
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')#'ignore ## to ignore the warning caused by palette
plt.figure(figsize=(2,2))
sns.boxplot(x=df['sibsp'],y=df['embark_town'],palette='Set1')## giving palrtte give the colurs to the plot
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['sibsp'],y=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['sibsp'],y=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['parch'],y=df['survived'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['parch'],y=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['parch'],y=df['sex'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['parch'],y=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['parch'],y=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['parch'],y=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['parch'],y=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['fare'],y=df['survived'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['fare'],y=df['sex'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['fare'],y=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['fare'],y=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['fare'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['fare'],y=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['fare'],y=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['fare'],y=df['alone'])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  891 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['pclass'],y=df['survived'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['pclass'],y=df['sex'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['pclass'],y=df['class'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['pclass'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['pclass'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(3,3))
sns.boxplot(x=df['pclass'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['pclass'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['sibsp'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['age'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=df['survived'],hue=df['sex']) ## adding hue give the legends to the plots
plt.show()

# %%
## bivariant (striplot)
plt.figure(figsize=(2,2))
sns.stripplot(x=df['class'],hue=df['sex'])
plt.show()
plt.figure(figsize=(2,2))
sns.swarmplot(x=df['class'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.stripplot(x=df['class'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['class'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['class'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['class'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['class'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['class'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['sex'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['sex'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['sex'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['sex'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['sex'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['sex'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['embarked'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['embarked'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['embarked'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['embarked'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['embarked'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['who'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['who'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['who'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['who'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['adult_male'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['adult_male'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['adult_male'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['embark_town'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['adult_male'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.stripplot(x=df['alive'],hue=df['alone'])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  891 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
plt.figure(figsize=(2,2,))
sns.swarmplot( data=df,x='sex',hue='survived') #swarmplot -> distribution of a numerical variable across categories
plt.show()

# %%
#multivariant scatter plot
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='pclass',hue='sex')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='age',hue='sex')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='sibsp',hue='sex')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='parch',hue='sex')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='fare',hue='sex')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='age',hue='sex')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='sibsp',hue='sex')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='parch',hue='sex')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='fare',hue='sex')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='sibsp',hue='sex')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='fare',hue='sex')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='sibsp', y='parch',hue='sex')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='sibsp', y='fare',hue='sex')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='parch', y='fare',hue='sex')
plt.show()                 ### can use hue as all categorical values for each pair o (for 15 pairs)

# %%
#embarked
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='parch', y='fare',hue='embarked')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='sibsp', y='fare',hue='embarked')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='sibsp', y='parch',hue='embarked')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='fare',hue='embarked')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='parch',hue='embarked')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='fare',hue='embarked')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='sibsp',hue='embarked')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='parch',hue='embarked')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='sibsp',hue='embarked')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='age',hue='embarked')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='fare',hue='embarked')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='parch',hue='embarked')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='sibsp',hue='embarked')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='age',hue='embarked')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='pclass',hue='embarked')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  891 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='pclass',hue='class')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='age',hue='class')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='sibsp',hue='class')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='parch',hue='class')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='fare',hue='class')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='age',hue='class')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='sibsp',hue='class')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='parch',hue='class')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='sibsp',hue='class')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='fare',hue='class')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='parch',hue='class')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='fare',hue='class')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='sibsp', y='parch',hue='class')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='sibsp', y='fare',hue='class')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='parch', y='fare',hue='class')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='pclass',hue='who')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='age',hue='who')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='sibsp',hue='who')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='parch',hue='who')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='fare',hue='who')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='age',hue='who')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='sibsp',hue='who')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='parch',hue='who')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='sibsp',hue='who')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='fare',hue='who')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='parch',hue='who')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='fare',hue='who')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='sibsp', y='parch',hue='who')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='sibsp', y='fare',hue='who')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='parch', y='fare',hue='who')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='pclass',hue='adult_male')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='age',hue='adult_male')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='sibsp',hue='who')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='parch',hue='adult_male')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='fare',hue='adult_male')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='age',hue='adult_male')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='sibsp',hue='adult_male')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='parch',hue='adult_male')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='sibsp',hue='adult_male')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='fare',hue='adult_male')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='parch',hue='adult_male')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='fare',hue='adult_male')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='sibsp', y='parch',hue='adult_male')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='sibsp', y='fare',hue='adult_male')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='parch', y='fare',hue='adult_male')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='pclass',hue='embark_town')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='age',hue='embark_town')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='sibsp',hue='embark_town')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='parch',hue='embark_town')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='fare',hue='embark_town')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='age',hue='embark_town')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='sibsp',hue='embark_town')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='parch',hue='embark_town')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='sibsp',hue='embark_town')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='fare',hue='embark_town')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='parch',hue='embark_town')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='fare',hue='embark_town')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='sibsp', y='parch',hue='embark_town')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='sibsp', y='fare',hue='embark_town')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='parch', y='fare',hue='embark_town')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='pclass',hue='alive')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='age',hue='alive')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='sibsp',hue='alive')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='parch',hue='embark_town')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='fare',hue='alive')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='age',hue='alive')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='sibsp',hue='alive')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='parch',hue='alive')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='sibsp',hue='alive')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='fare',hue='alive')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='parch',hue='alive')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='fare',hue='alive')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='sibsp', y='parch',hue='alive')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='sibsp', y='fare',hue='alive')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='parch', y='fare',hue='alive')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='fare',hue='alone')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='age',hue='alone')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='sibsp',hue='alone')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='parch',hue='alone')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='sibsp',hue='alone')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='pclass', y='fare',hue='alone')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='parch',hue='alone')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='age', y='fare',hue='alone')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='sibsp', y='parch',hue='alone')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='sibsp', y='fare',hue='alone')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='parch', y='fare',hue='alone')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='pclass',hue='alone')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='age',hue='alone')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='sibsp',hue='alone')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.scatterplot(data=df, x='survived', y='parch',hue='alone')
plt.show()
