# %%
import pandas as pd
#Reading csv file
uber_data=pd.read_csv("Uber_Drives_2016.csv")
uber_data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
#shape of a Dataframe
print(uber_data.shape)
# Out:
# (1156, 7)

# %%
#info about the Dataframe (columns, Datatype
print(uber_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB
# None

# %%
# Checking for null values
print(uber_data.isnull().sum())
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
null_rows = uber_data[uber_data.isnull().any(axis = 1)]
print(null_rows)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 32      1/19/2016 9:09    1/19/2016 9:23  Business       Whitebridge
# 85      2/9/2016 10:54    2/9/2016 11:07  Personal       Whitebridge
# 86      2/9/2016 11:43    2/9/2016 11:50  Personal        Northwoods
# 87      2/9/2016 13:36    2/9/2016 13:52  Personal        Tanglewood
# ...                ...               ...       ...               ...
# 1066  12/19/2016 14:37  12/19/2016 14:50  Business  Unknown Location
# 1069  12/19/2016 19:05  12/19/2016 19:17  Business         Islamabad
# 1071   12/20/2016 8:49   12/20/2016 9:24  Business  Unknown Location
# 1143  12/29/2016 20:53  12/29/2016 21:42  Business           Kar?chi
# 1155            Totals               NaN       NaN               NaN
#
#                     STOP*   MILES* PURPOSE*
# 1             Fort Pierce      5.0      NaN
# 32    Lake Wellingborough      7.2      NaN
# ...

# %%
null_rows = uber_data[uber_data['START_DATE*'].isnull()]
print(null_rows)
# Out:
# Empty DataFrame
# Columns: [START_DATE*, END_DATE*, CATEGORY*, START*, STOP*, MILES*, PURPOSE*]
# Index: []

# %%
uber_data = uber_data.rename(columns = {'START_DATE*' : 'START_DATE', 'END_DATE*' : 'END_DATE', 'START*' : 'START'})
uber_data
# Out:
#             START_DATE          END_DATE CATEGORY*             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
# Display first 5 rows
uber_data.head(5)
# Out:
#        START_DATE        END_DATE CATEGORY*        START            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
# Display last 5 rows
uber_data.tail(5)
# Out:
#             START_DATE          END_DATE CATEGORY*             START  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
# Display fist row
uber_data.iloc[0]
# Out:
# START_DATE    1/1/2016 21:11
# END_DATE      1/1/2016 21:17
# CATEGORY*           Business
# START            Fort Pierce
# STOP*            Fort Pierce
# MILES*                   5.1
# PURPOSE*      Meal/Entertain
# Name: 0, dtype: object

# %%
# Display rows between 2 to 8
uber_data.iloc[2:8]
# Out:
#        START_DATE        END_DATE CATEGORY*            START            STOP*  \
# 2  1/2/2016 20:25  1/2/2016 20:38  Business      Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business      Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business      Fort Pierce  West Palm Beach
# 5  1/6/2016 17:15  1/6/2016 17:19  Business  West Palm Beach  West Palm Beach
# 6  1/6/2016 17:30  1/6/2016 17:35  Business  West Palm Beach       Palm Beach
# 7  1/7/2016 13:27  1/7/2016 13:33  Business             Cary             Cary
#
#    MILES*         PURPOSE*
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit
# 5     4.3   Meal/Entertain
# 6     7.1          Meeting
# 7     0.8          Meeting

# %%
# Display rows 2 to 7
uber_data.iloc[2:8,1:3]
# Out:
#          END_DATE CATEGORY*
# 2  1/2/2016 20:38  Business
# 3  1/5/2016 17:45  Business
# 4  1/6/2016 15:49  Business
# 5  1/6/2016 17:19  Business
# 6  1/6/2016 17:35  Business
# 7  1/7/2016 13:33  Business

# %%
import pandas as pd
#Reading csv file
uber_data=pd.read_csv("Uber_Drives_2016.csv")
uber_data.head()
uber_data['START_DATE*']
# Out:
# 0         1/1/2016 21:11
# 1          1/2/2016 1:25
# 2         1/2/2016 20:25
# 3         1/5/2016 17:31
# 4         1/6/2016 14:42
#               ...
# 1151    12/31/2016 13:24
# 1152    12/31/2016 15:03
# 1153    12/31/2016 21:32
# 1154    12/31/2016 22:08
# 1155              Totals
# Name: START_DATE*, Length: 1156, dtype: object

# %%
# Display first 1,2,3 row and starting column,stop and miles
uber_data.loc[[1,2,3],['START*','STOP*','MILES*']]
# Out:
#         START*        STOP*  MILES*
# 1  Fort Pierce  Fort Pierce     5.0
# 2  Fort Pierce  Fort Pierce     4.8
# 3  Fort Pierce  Fort Pierce     4.7

# %%
temp=pd.DataFrame({'A':[1,2,3,4],'B':[10,20,30,40],'C':['2025-1-19','2025-1-21','2025-1-11','2025-1-22']})
temp
# Out:
#    A   B          C
# 0  1  10  2025-1-19
# 1  2  20  2025-1-21
# 2  3  30  2025-1-11
# 3  4  40  2025-1-22

# %%
temp=pd.DataFrame({'A':[1,2,3,4],'B':[10,20,30,40],'C':['2025-1-19','2025-1-21','2025-1-11','2025-1-22']})
temp.dtypes
# Out:
# A     int64
# B     int64
# C    object
# dtype: object

# %%
#to convert str datatype into datetime format
temp['C'] = pd.to_datetime(temp['C'])
temp.dtypes
# Out:
# A             int64
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
# To convert int datatype into str datatype
temp['A'] = temp['A'].astype(str)
temp.dtypes
# Out:
# A            object
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
# convert the  datatype in dateformat
temp['C'] = pd.to_datetime(temp['C'],format="%d-%m-%y", errors = 'coerce')
temp.dtypes
# Out:
# A            object
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
#Boolean Indexing and Filtering
a = uber_data[uber_data['MILES*'] < 1]
a
# Out:
#            START_DATE*         END_DATE* CATEGORY*                 START*  \
# 7       1/7/2016 13:27    1/7/2016 13:33  Business                   Cary
# 44     1/26/2016 17:27   1/26/2016 17:29  Business                   Cary
# 120    2/17/2016 16:38   2/17/2016 16:43  Business             Katunayaka
# 189     3/4/2016 16:16    3/4/2016 16:22  Business    Fayetteville Street
# 212    3/11/2016 10:29   3/11/2016 10:36  Business  Congress Ave District
# 258    3/21/2016 16:05   3/21/2016 16:13  Business               Downtown
# 292     4/1/2016 16:52    4/1/2016 16:57  Personal              Kissimmee
# 418     6/8/2016 14:31    6/8/2016 14:37  Business         Medical Centre
# 420     6/8/2016 17:16    6/8/2016 17:18  Business                   Soho
# 421     6/8/2016 17:59    6/8/2016 18:05  Business                Tribeca
# 516     7/5/2016 16:48    7/5/2016 16:52  Business            Whitebridge
# 567    7/18/2016 20:28   7/18/2016 20:32  Business              Hazelwood
# ...

# %%
# if you need miles clumn whose values >6
df2=uber_data.loc[uber_data['MILES*']>6,['MILES*']]          
df2
# Out:
#        MILES*
# 4        63.7
# 6         7.1
# 8         8.3
# 9        16.5
# 10       10.8
# ...       ...
# 1144     12.9
# 1152     16.2
# 1153      6.4
# 1154     48.2
# 1155  12204.7
#
# [569 rows x 1 columns]

# %%
 # if you need all the columns where miles>6
df3=uber_data.loc[uber_data['MILES*']>6]          
df3
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 6       1/6/2016 17:30    1/6/2016 17:35  Business   West Palm Beach
# 8       1/10/2016 8:05    1/10/2016 8:25  Business              Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business           Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business          New York
# ...                ...               ...       ...               ...
# 1144  12/29/2016 23:14  12/29/2016 23:47  Business  Unknown Location
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 4      West Palm Beach     63.7  Customer Visit
# ...

# %%
uber_data.loc[uber_data['START*'] == "New York"]
# Out:
#          START_DATE*        END_DATE* CATEGORY*    START*             STOP*  \
# 10   1/10/2016 15:08  1/10/2016 15:51  Business  New York            Queens
# 22   1/12/2016 16:02  1/12/2016 17:00  Business  New York     Queens County
# 106  2/14/2016 16:35  2/14/2016 17:02  Business  New York  Long Island City
# 423  6/10/2016 15:19  6/10/2016 16:28  Business  New York           Jamaica
#
#      MILES* PURPOSE*
# 10     10.8  Meeting
# 22     15.1  Meeting
# 106    13.0  Meeting
# 423    16.3  Meeting

# %%
uber_data.loc[uber_data['START*'].isin(['New York','Cary'])]
# Out:
#            START_DATE*         END_DATE* CATEGORY*    START*          STOP*  \
# 7       1/7/2016 13:27    1/7/2016 13:33  Business      Cary           Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business      Cary    Morrisville
# 10     1/10/2016 15:08   1/10/2016 15:51  Business  New York         Queens
# 22     1/12/2016 16:02   1/12/2016 17:00  Business  New York  Queens County
# 28     1/15/2016 11:43   1/15/2016 12:03  Business      Cary         Durham
# ...                ...               ...       ...       ...            ...
# 1049  12/13/2016 20:20  12/13/2016 20:29  Business      Cary           Cary
# 1050  12/14/2016 16:52  12/14/2016 17:10  Business      Cary           Cary
# 1051  12/14/2016 17:22  12/14/2016 17:34  Business      Cary           Cary
# 1052  12/14/2016 17:50  12/14/2016 18:00  Business      Cary    Morrisville
# 1054  12/15/2016 14:20  12/15/2016 14:54  Business      Cary    Morrisville
#
#       MILES*        PURPOSE*
# ...

# %%
df1 = uber_data.loc[(uber_data['MILES*'] > 10) & (uber_data['START*'].isin(['Cary', 'Morrisville']))]
df1
# Out:
#            START_DATE*         END_DATE* CATEGORY* START*          STOP*  \
# 28     1/15/2016 11:43   1/15/2016 12:03  Business   Cary         Durham
# 34     1/20/2016 10:36   1/20/2016 11:11  Business   Cary        Raleigh
# 46     1/27/2016 10:19   1/27/2016 10:48  Business   Cary        Raleigh
# 50     1/28/2016 12:28   1/28/2016 13:00  Business   Cary        Raleigh
# 55     1/29/2016 11:43   1/29/2016 12:03  Business   Cary         Durham
# ...                ...               ...       ...    ...            ...
# 990   11/22/2016 15:51  11/22/2016 16:43  Business   Cary           Cary
# 997   11/25/2016 11:47  11/25/2016 12:04  Business   Cary         Durham
# 1035   12/9/2016 22:03   12/9/2016 22:57  Business   Cary           Cary
# 1036  12/10/2016 12:43  12/10/2016 13:16  Business   Cary  Fuquay-Varina
# 1054  12/15/2016 14:20  12/15/2016 14:54  Business   Cary    Morrisville
#
#       MILES*        PURPOSE*
# 28      10.4  Meal/Entertain
# 34      17.1         Meeting
# ...

# %% [markdown]
# # Sort

# %%
# by default it returns ASC order
uber_data.sort_values(by = 'MILES*')
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 120    2/17/2016 16:38   2/17/2016 16:43  Business        Katunayaka
# 420     6/8/2016 17:16    6/8/2016 17:18  Business              Soho
# 44     1/26/2016 17:27   1/26/2016 17:29  Business              Cary
# 516     7/5/2016 16:48    7/5/2016 16:52  Business       Whitebridge
# 1111   12/25/2016 0:10   12/25/2016 0:14  Business            Lahore
# ...                ...               ...       ...               ...
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 120         Katunayaka      0.5  Errand/Supplies
# ...

# %%
# by default it returns ASC order
uber_data.sort_values(by = 'MILES*',ascending = False)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1155            Totals               NaN       NaN               NaN
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# ...                ...               ...       ...               ...
# 1111   12/25/2016 0:10   12/25/2016 0:14  Business            Lahore
# 516     7/5/2016 16:48    7/5/2016 16:52  Business       Whitebridge
# 420     6/8/2016 17:16    6/8/2016 17:18  Business              Soho
# 120    2/17/2016 16:38   2/17/2016 16:43  Business        Katunayaka
# 44     1/26/2016 17:27   1/26/2016 17:29  Business              Cary
#
#                  STOP*   MILES*         PURPOSE*
# 1155               NaN  12204.7              NaN
# ...

# %%
# by default it returns ASC order of multipile order
uber_data.sort_values(by = ['START*','MILES*'], ascending = [True,False])
# Out:
#            START_DATE*         END_DATE* CATEGORY*         START*  \
# 906    11/4/2016 21:04   11/4/2016 21:20  Business          Agnew
# 911    11/6/2016 10:50   11/6/2016 11:04  Business          Agnew
# 908     11/5/2016 8:34    11/5/2016 8:43  Business          Agnew
# 910    11/5/2016 19:20   11/5/2016 19:28  Business          Agnew
# 879   10/30/2016 12:58  10/30/2016 13:18  Business         Almond
# ...                ...               ...       ...            ...
# 889    11/1/2016 17:35   11/1/2016 17:42  Business    Whitebridge
# 890    11/1/2016 19:14   11/1/2016 19:20  Business    Whitebridge
# 516     7/5/2016 16:48    7/5/2016 16:52  Business    Whitebridge
# 870   10/28/2016 18:13  10/28/2016 20:07  Business  Winston Salem
# 1155            Totals               NaN       NaN            NaN
#
#             STOP*   MILES*         PURPOSE*
# 906          Cory      4.3              NaN
# 911   Renaissance      2.4              NaN
# ...

# %% [markdown]
# # Conditionally adding columns

# %%
uber_data['price'] = 100;
uber_data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*  price
# 0          Fort Pierce      5.1   Meal/Entertain    100
# ...

# %%
# Adding a separate column using conditional statement
import numpy as np 
uber_data["MILES_CAT"] = np.where(uber_data['MILES*'] > 100,"Long trip", "Short trip")
uber_data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*  price   MILES_CAT
# 0     5.1   Meal/Entertain    100  Short trip
# 1     5.0              NaN    100  Short trip
# 2     4.8  Errand/Supplies    100  Short trip
# 3     4.7          Meeting    100  Short trip
# 4    63.7   Customer Visit    100  Short trip

# %%
condition = [(uber_data["MILES*"] > 100), (uber_data['MILES*'] > 50) & (uber_data['MILES*'] > 100), (uber_data['MILES*'] > 50)]
categories = ["Long trip", 'Medium trip', 'short trip']
uber_data["MILES_CAT"] = np.select(condition,categories, default = "Unkonow")
uber_data.drop(columns = ['MILES_CAT'], inplace = True)
uber_data.tail(50)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1106  12/24/2016 12:51  12/24/2016 12:53  Business            Lahore
# 1107  12/24/2016 13:08  12/24/2016 13:29  Business            Lahore
# 1108  12/24/2016 17:12  12/24/2016 17:27  Business            Lahore
# 1109  12/24/2016 19:12  12/24/2016 19:27  Business            Lahore
# 1110  12/24/2016 22:04  12/24/2016 22:09  Business            Lahore
# 1111   12/25/2016 0:10   12/25/2016 0:14  Business            Lahore
# 1112  12/25/2016 19:15  12/25/2016 19:26  Business            Lahore
# 1113  12/25/2016 21:58  12/25/2016 22:04  Business            Lahore
# 1114   12/26/2016 8:30   12/26/2016 8:41  Business            Lahore
# 1115   12/26/2016 9:05   12/26/2016 9:19  Business            Lahore
# 1116  12/26/2016 10:15  12/26/2016 10:36  Business            Lahore
# 1117  12/26/2016 11:29  12/26/2016 11:42  Business            Lahore
# 1118  12/26/2016 13:09  12/26/2016 13:43  Business            Lahore
# ...

# %% [markdown]
# # Group By

# %%
import pandas as pd

# Sample dataset
data = {
    'Employee': ['Asha', 'Ravi', 'Meena', 'Ravi', 'Asha', 'Meena', 'Ravi', 'Asha'],
    'Department': ['HR', 'IT', 'Finance', 'IT', 'HR', 'Finance', 'IT', 'HR'],
    'Sales': [20000, 30000, 25000, 40000, 20000, 27000, 35000, 22000],
     'Units': [2, 3, 2, 4, 2, 3, 4, 2],
    'Month': ['Jan', 'Jan', 'Jan', 'Feb', 'Feb', 'Feb', 'Mar', 'Mar']
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Employee Department  Sales  Units Month
# 0     Asha         HR  20000      2   Jan
# 1     Ravi         IT  30000      3   Jan
# 2    Meena    Finance  25000      2   Jan
# 3     Ravi         IT  40000      4   Feb
# 4     Asha         HR  20000      2   Feb
# 5    Meena    Finance  27000      3   Feb
# 6     Ravi         IT  35000      4   Mar
# 7     Asha         HR  22000      2   Mar

# %%
c=df.groupby('Department')['Sales'].count()   # Count
print("<====================================Count========>")
print(c)
c=df.groupby('Department')['Sales'].sum()
print("<====================================Sum==========>")
print(c)
c=df.groupby('Department')['Sales'].mean()
print("<=====================================Mean==========>")
print(c)
c=df.groupby('Department')['Sales'].median()
print("<====================================Median==========>")
print(c)
c=df.groupby('Department')['Sales'].max()
print("<====================================Max==========>")
print(c)
c=df.groupby('Department')['Sales'].min()
print("<====================================Min==========>")
print(c)
c=df.groupby('Department')['Sales'].nunique()
print("<====================================Unique==========>")
print(c)
# Out:
# <====================================Count========>
# Department
# Finance    2
# HR         3
# IT         3
# Name: Sales, dtype: int64
# <====================================Sum==========>
# Department
# Finance     52000
# HR          62000
# IT         105000
# Name: Sales, dtype: int64
# <=====================================Mean==========>
# Department
# Finance    26000.000000
# HR         20666.666667
# IT         35000.000000
# Name: Sales, dtype: float64
# <====================================Median==========>
# Department
# Finance    26000.0
# HR         20000.0
# IT         35000.0
# Name: Sales, dtype: float64
# <====================================Max==========>
# Department
# Finance    27000
# HR         22000
# IT         40000
# Name: Sales, dtype: int64
# <====================================Min==========>
# Department
# Finance    25000
# HR         20000
# IT         30000
# Name: Sales, dtype: int64
# <====================================Unique==========>
# ...

# %% [markdown]
# # 1) Built-in aggregate functions (single-column)

# %%
c=df.groupby('Department')['Sales'].agg(['sum','mean','median','count','max','min','nunique'])
c
# Out:
#                sum          mean   median  count    max    min  nunique
# Department
# Finance      52000  26000.000000  26000.0      2  27000  25000        2
# HR           62000  20666.666667  20000.0      3  22000  20000        2
# IT          105000  35000.000000  35000.0      3  40000  30000        3

# %% [markdown]
# # 2) Multiple aggregations on multiple columns (list / dict style)

# %% [markdown]
# ## 2.1 List-style (same functions for each column)

# %%
c=df.groupby('Department')[['Sales','Units']].agg(['count','sum','mean','max','min'])
c
# Out:
#            Sales                                     Units                    \
#            count     sum          mean    max    min count sum      mean max
# Department
# Finance        2   52000  26000.000000  27000  25000     2   5  2.500000   3
# HR             3   62000  20666.666667  22000  20000     3   6  2.000000   2
# IT             3  105000  35000.000000  40000  30000     3  11  3.666667   4
#
#
#            min
# Department
# Finance      2
# HR           2
# IT           3

# %% [markdown]
# ## 2.2 Dict-style (different functions per column)

# %%
c=df.groupby('Department').agg({
    'Sales':['sum','mean','max'],
    'Units':['count','max','min']
})
c
# Out:
#              Sales                      Units
#                sum          mean    max count max min
# Department
# Finance      52000  26000.000000  27000     2   3   2
# HR           62000  20666.666667  22000     3   2   2
# IT          105000  35000.000000  40000     3   4   3

# %% [markdown]
# ## 3) Named aggregation (clean column names, recommended)

# %%
c=df.groupby('Department').agg(
    total_sales = ('Sales', 'sum'),
    avg_sales   = ('Sales', 'mean'),
    max_sales   = ('Sales', 'max'),
    units_sold  = ('Units', 'sum'),
    avg_units   = ('Units', 'mean'),
    emp_count   = ('Employee', 'nunique')
).reset_index()
c
# Out:
#   Department  total_sales     avg_sales  max_sales  units_sold  avg_units  \
# 0    Finance        52000  26000.000000      27000           5   2.500000
# 1         HR        62000  20666.666667      22000           6   2.000000
# 2         IT       105000  35000.000000      40000          11   3.666667
#
#    emp_count
# 0          1
# 1          1
# 2          1
